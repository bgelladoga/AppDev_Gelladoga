# %% [markdown]
# #**Exercise 1**

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Print('Hello world!')
#
# "Print" is not defined because it is starts with a capital letter.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# print'Hello world!')
#
# It has no open paranthesis.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# print('Hello world!)
#
# Missing string lateral.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# print('Hello world!'')
#
# undetermined string lateral.

# %% [markdown]
# #**Excercise2**

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# x = 43
# x = X + 1
# print(x)
#
# 'X' Is not defined.
